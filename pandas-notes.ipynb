# %% [markdown]
# <a href="https://www.kaggle.com/code/hilalalpak/pandas-notes?scriptVersionId=178356054" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ****Pandas serileri; Tek boyutlu ve index bilgisi barındıran veri tipidir.
#     Pandas DataFrame; Çok boyutlu ve index bilgisi barındıran veri tipidir.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd

# %%
s = pd.Series([34,12, 27, 15])

# %% [markdown]
# ****Index bilgisi iç özelliktir.

# %%
type(s)
s.index
s.dtype
s.size
s.ndim
s.values
# Out:
# pandas.core.series.Series
# RangeIndex(start=0, stop=4, step=1)
# dtype('int64')
# 4
# 1
# array([34, 12, 27, 15])

# %% [markdown]
# ****s.values; tipi np.array çıkacaktır.Index bilgisi ile ilgilenmediğimizi belirttiğimiz için numpy array olarak sonuç gelir.

# %%
s.head()
s.tail()
# Out:
# 0    34
# 1    12
# 2    27
# 3    15
# dtype: int64
# 0    34
# 1    12
# 2    27
# 3    15
# dtype: int64

# %% [markdown]
# > Veri Okuma;
#        df = pd.read_csv("file_path")

# %%
import seaborn as sns

df = sns.load_dataset("titanic")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ****Object tipi de kategorik bir değişkendir.
#
# > ###df.head(), df.shape, df.tail(), df.columns, df.index

# %%
df.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
##En az bir tane dahi olsa eksik veri var mı;
df.isnull().values.any()
# Out:
# True

# %%
##Her bir değişkende kaç eksik değer var;
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64
