# %% [markdown]
# <a href="https://www.kaggle.com/code/hilalalpak/pandas-notes2?scriptVersionId=178367479" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import seaborn as sns
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
##df[0:13]
df.drop(1, axis=0).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
delete_indexes = [1, 3, 5]
df.drop(delete_indexes, axis=0).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
# 7         0       3    male   2.0      3      1  21.0750        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 4    man        True  NaN  Southampton    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False

# %% [markdown]
# > df.drop(delete_indexes, axis=0, inplace=True)
#        inplace=True; işlemi kalıcı hale getirmek için, atama yapmak yerine kullanılabilir.

# %%
##Değişkeni indexe çevirmek;
##df["age"] = df.age

df.index = df["age"]
df.drop("age", axis=1).head()
# Out:
#       survived  pclass     sex  sibsp  parch     fare embarked  class    who  \
# age
# 22.0         0       3    male      1      0   7.2500        S  Third    man
# 38.0         1       1  female      1      0  71.2833        C  First  woman
# 26.0         1       3  female      0      0   7.9250        S  Third  woman
# 35.0         1       1  female      1      0  53.1000        S  First  woman
# 35.0         0       3    male      0      0   8.0500        S  Third    man
#
#       adult_male deck  embark_town alive  alone
# age
# 22.0        True  NaN  Southampton    no  False
# 38.0       False    C    Cherbourg   yes  False
# 26.0       False  NaN  Southampton   yes   True
# 35.0       False    C  Southampton   yes  False
# 35.0        True  NaN  Southampton    no   True

# %%
##indexi değişkene atamak;
df["age"] = df.index

# %% [markdown]
# ****Yazacağımız değişken varsa değiştirir, yoksa yeni değişken atama yapar.

# %% [markdown]
# > Indexi resetlemek; df.reset_index()

# %%
pd.set_option("display.max_columns", None)
df.head()
# Out:
#       survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# age
# 22.0         0       3    male  22.0      1      0   7.2500        S  Third
# 38.0         1       1  female  38.0      1      0  71.2833        C  First
# 26.0         1       3  female  26.0      0      0   7.9250        S  Third
# 35.0         1       1  female  35.0      1      0  53.1000        S  First
# 35.0         0       3    male  35.0      0      0   8.0500        S  Third
#
#         who  adult_male deck  embark_town alive  alone
# age
# 22.0    man        True  NaN  Southampton    no  False
# 38.0  woman       False    C    Cherbourg   yes  False
# 26.0  woman       False  NaN  Southampton   yes   True
# 35.0  woman       False    C  Southampton   yes  False
# 35.0    man        True  NaN  Southampton    no   True

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# ****reset_index() fonksiyonunda drop=True kullanımı, DataFrame'deki indeksi sıfırlamak istediğinizde, indeksi sıfırlarken mevcut indeksi DataFrame'den kaldırır.

# %%
##Değişken varlığını sorgulamak;
"age" in df
# Out:
# True

# %% [markdown]
# ****Seçim işlemi yaparken df["age"] tipi pandas serisi iken df[["age"]] tipi DataFrame dir.

# %%
df[["age", "alive"]].head()
# Out:
#     age alive
# 0  22.0    no
# 1  38.0   yes
# 2  26.0   yes
# 3  35.0   yes
# 4  35.0    no

# %% [markdown]
# > Alternatif yol;
#    col_names = ["age", "alive"]
#     df[col_names

# %%
df["age2"] = df["age"] **3
df["age3"] = df["age2"] / df["age"]
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone     age2    age3
# 0    man        True  NaN  Southampton    no  False  10648.0   484.0
# 1  woman       False    C    Cherbourg   yes  False  54872.0  1444.0
# 2  woman       False  NaN  Southampton   yes   True  17576.0   676.0
# 3  woman       False    C  Southampton   yes  False  42875.0  1225.0
# 4    man        True  NaN  Southampton    no   True  42875.0  1225.0

# %% [markdown]
# **** df.columns.str.contains("age"); içinde age geçen değişkenleri seçer. Başına ~ konursa onun dışındaki değişkenleri seçer.

# %%
##Iloc(int based) & Loc(label based)
df.iloc[0:3]
df.loc[0:3, "age"]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone     age2    age3
# 0    man        True  NaN  Southampton    no  False  10648.0   484.0
# 1  woman       False    C    Cherbourg   yes  False  54872.0  1444.0
# 2  woman       False  NaN  Southampton   yes   True  17576.0   676.0
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# Name: age, dtype: float64

# %%
##Koşullu İşlemler;
df[df["age"]<50].head()
df[df["age"]<50]["age"].count() ##(tüm değişkenleri getirmemesi için "age" belirtilir.)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone     age2    age3
# 0    man        True  NaN  Southampton    no  False  10648.0   484.0
# 1  woman       False    C    Cherbourg   yes  False  54872.0  1444.0
# 2  woman       False  NaN  Southampton   yes   True  17576.0   676.0
# 3  woman       False    C  Southampton   yes  False  42875.0  1225.0
# 4    man        True  NaN  Southampton    no   True  42875.0  1225.0
# 640

# %% [markdown]
# **** Birden fazla koşul bildirilirse &(ve) veya |(veya) kullanılır.
