# %% [markdown]
# <a href="https://www.kaggle.com/code/hilalalpak/veri-g-rselle-tirme-notes?scriptVersionId=178687680" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import seaborn as sns
pd.set_option("display.max_columns", None)
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ****Matplotlib: Düşük seviyeden görselleştirme yapar.
#     Seaborn: Yüksek seviyeden görselleştirme sağlar.
#
# ****Kategorik değişken; Sütun grafik. countplot bar
#     Sayısal değişken; Hist, boxplot(aykırı değerleri de gösterir)

# %%
import matplotlib.pyplot as plt
df["sex"].value_counts().plot(kind="bar")
plt.show()
# Out:
# <Axes: xlabel='sex'>

# %%
plt.hist(df["age"])
plt.show()
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df["fare"])
plt.show()
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ab0fb408d90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ab0fb4092d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ab0fb408af0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ab0fb409810>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ab0fb409ab0>],
#  'means': []}

# %% [markdown]
# **** plot; x = np.array([""])
#            y = np.array([""])
#            plt.plot(x, y)
#
#            plt.plot(x, y, "o")
#
# **** marker; plt.plot(y, marker= "o") ---"o", "*", "+", "x",...)
#
# **** line; plt.plot(y, linestyle="", color="")
#             --- "dashed", "dashdot", "dotted
#             --- "r"
#
# **** labels; plt.title("")
#              plt.xlabel("")
#              plt.grid()
#
# **** subplot; plt.subplot(satır, sütun, kaçıncı bölüm)

# %%
df2 = sns.load_dataset("tips")
df2.head()
df2["sex"].value_counts()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
sns.countplot(x=df2["sex"], data=df)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x=df2["tip"])
plt.show()
# Out:
# <Axes: xlabel='tip'>

# %%
df2["total_bill"].hist()
plt.show()
# Out:
# <Axes: >
